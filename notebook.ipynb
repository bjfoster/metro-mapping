# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import importlib

import metro.core
import metro.live

importlib.reload(metro.core)
importlib.reload(metro.live)
import os

# %%
project = metro.core.Project(R'nyc_gtfs.zip')

# %%
project.load()

# %%
project.agency.routes['H'].
# Out:
# ' Queens."'

# %%
service = metro.live.LiveService()
route_id = '3'
feed = service.get_gtfs_realtime_feed(service.realtime_feeds[route_id])

for e in feed.entity:
    if e.HasField('trip_update'):
        if e.trip_update.trip.route_id == route_id:
            print(e.trip_update)
# Out:
# trip {
#   trip_id: "070100_3..N01R"
#   start_date: "20220517"
#   route_id: "3"
# }
# stop_time_update {
#   arrival {
#     time: 1652806351
#   }
#   departure {
#     time: 1652806501
#   }
#   stop_id: "302N"
# }
# stop_time_update {
#   arrival {
#     time: 1652806621
#   }
#   stop_id: "301N"
# }
#
# trip {
#   trip_id: "070950_3..S01R"
#   start_date: "20220517"
#   route_id: "3"
# }
# stop_time_update {
#   arrival {
#     time: 1652806500
#   }
#   departure {
#     time: 1652806500
#   }
#   stop_id: "255S"
# }
# stop_time_update {
#   arrival {
#     time: 1652806560
#   }
#   departure {
#     time: 1652806560
#   }
#   stop_id: "256S"
# }
# stop_time_update {
#   arrival {
#     time: 1652806650
#   }
#   stop_id: "257S"
# }
#
# trip {
#   trip_id: "070950_3..N01R"
#   start_date: "20220517"
#   route_id: "3"
# }
# stop_time_update {
#   arrival {
#     time: 1652806399
#   }
#   departure {
#     time: 1652806399
#   }
#   stop_id: "225N"
# }
# stop_time_update {
# ...

# %%
import urllib

# %%
urllib.request.urlopen('https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-ace')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# d:\Repos\metro-mapping\notebook.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Repos/metro-mapping/notebook.ipynb#ch0000012?line=0'>1</a> urllib.request.urlopen('https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-ace')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     <a href='file:///c%3A/Users/bfoster/AppData/Local/Programs/Python/Python310/lib/urllib/request.py?line=213'>214</a> else:
#     <a href='file:///c%3A/Users/bfoster/AppData/Local/Programs/Python/Python310/lib/urllib/request.py?line=214'>215</a>     opener = _opener
# ...

# %%
import urllib.parse

# %%
urllib.parse.ParseResult
# Out:
# urllib.parse.ParseResult
