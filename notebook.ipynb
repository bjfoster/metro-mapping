# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import importlib

import metro.core as mc
importlib.reload(mc)
import os

# %%
df = pd.read_csv(R'nyc\agency.txt')
a = mc.Agency(df)

routes = pd.read_csv(R'nyc\routes.txt')
stops = pd.read_csv(R'nyc\stops.txt')
services = pd.read_csv(R'nyc\calendar.txt')
shapes = pd.read_csv(R'nyc\shapes.txt')
trips = pd.read_csv(R'nyc\trips.txt')
stop_times = pd.read_csv(R'nyc\stop_times.txt')

a.generate_routes(routes)
a.generate_stops(stops)
a.generate_services(services)
a.generate_shapes(shapes)
a.generate_trips(trips)
a.generate_stop_times(stop_times)

# %%
a.cross_reference_objects()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 a.cross_reference_objects()
#
# File c:\Local\New folder\metro-mapping\metro\core.py:120, in Agency.cross_reference_objects(self)
#     118 self._cross_reference_trips()
#     119 self._cross_reference_stops()
# --> 120 self._cross_reference_stop_times()
#
# File c:\Local\New folder\metro-mapping\metro\core.py:106, in Agency._cross_reference_stop_times(self)
#     102     stop_time.assign_trip(self.trips[stop_time.trip_id])
#     104 for trip in self.trips.values():
# --> 106     stop_times = [
#     107         stop_time for stop_time in self.stop_times if stop_time.trip_id == trip.id]
#     108     trip.assign_stop_times(stop_times)
#     110 for stop in self.stops.values():
#
# File c:\Local\New folder\metro-mapping\metro\core.py:107, in <listcomp>(.0)
# ...

# %%
[stop for stop in a.stops]
# Out:
# ['⌛: Route: 1 Stop: Van Cortlandt Park-242 St: Arrival: 00:06:00 Departure: 00:06:00',
#  '⌛: Route: 1 Stop: 238 St: Arrival: 00:07:30 Departure: 00:07:30',
#  '⌛: Route: 1 Stop: 231 St: Arrival: 00:09:00 Departure: 00:09:00',
#  '⌛: Route: 1 Stop: Marble Hill-225 St: Arrival: 00:10:30 Departure: 00:10:30',
#  '⌛: Route: 1 Stop: 215 St: Arrival: 00:12:00 Departure: 00:12:00',
#  '⌛: Route: 1 Stop: 207 St: Arrival: 00:13:00 Departure: 00:13:00',
#  '⌛: Route: 1 Stop: Dyckman St: Arrival: 00:14:30 Departure: 00:14:30',
#  '⌛: Route: 1 Stop: 191 St: Arrival: 00:16:00 Departure: 00:16:00',
#  '⌛: Route: 1 Stop: 181 St: Arrival: 00:17:30 Departure: 00:17:30',
#  '⌛: Route: 1 Stop: 168 St-Washington Hts: Arrival: 00:19:30 Departure: 00:19:30',
#  '⌛: Route: 1 Stop: 157 St: Arrival: 00:21:00 Departure: 00:21:00',
#  '⌛: Route: 1 Stop: 145 St: Arrival: 00:23:00 Departure: 00:23:00',
#  '⌛: Route: 1 Stop: 137 St-City College: Arrival: 00:24:30 Departure: 00:24:30',
# ...
